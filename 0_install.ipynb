# %%
# !pip3 install requests
# Out:
# ...
#    ---------------------------------------- 0.0/64.7 kB ? eta -:--:--
#    ------------------------------------- -- 61.4/64.7 kB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 61.4/64.7 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 64.7/64.7 kB 495.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/159.4 kB ? eta -:--:--
#    -------------------------------------- - 153.6/159.4 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 159.4/159.4 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/107.0 kB ? eta -:--:--
#    -------------------------------------- - 102.4/107.0 kB ? eta -:--:--
#    -------------------------------------- - 102.4/107.0 kB ? eta -:--:--
#    -------------------------------------- 107.0/107.0 kB 887.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/71.0 kB ? eta -:--:--
# ...

# %%
# !pip3 install beautifulsoup4
# Out:
# ...
#    ---------------------------------------- 0.0/106.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/106.4 kB ? eta -:--:--
#    -------------------------- ------------ 71.7/106.4 kB 787.7 kB/s eta 0:00:01
#    -------------------------------------- 106.4/106.4 kB 882.1 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\irmin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
